# %% [markdown]
# ## About this
# THis is my first Jupyter notebook project
#
# - first
# - second
#     - sub first
#     - sub second
# - third
# - fourth

# %%
str ="tell me something new"
print("welcome")
print(str)
# Out:
# welcome
# tell me something new

# %% [markdown]
# ### Commands to run
# This will install all the packages mentioned in the txt file
# ```
# pip install -r requirements.txt
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Printing from code")
# Out:
# Printing from code
